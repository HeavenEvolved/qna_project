# %%
import os
import dotenv

# %%
os.path.abspath('doc_ai')
# Out:
# '/home/evo/Documents/Projects/Python/qna_project/doc_ai'

# %%
config = dotenv.dotenv_values()['HUGGINGFACEHUB_API_TOKEN']

# %%
config
# Out:
# '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'

# %%
(
    """Lol"""
    """ Hello"""
)
# Out:
# 'Lol Hello'

# %%
"     ".split() == True
# Out:
# False

# %%
import re
match = re.compile(r" ")

# %%
re.findall(match, "     ")
# Out:
# [' ', ' ', ' ', ' ', ' ']

# %%
filters = [
    lambda x: len(x),
    lambda x: x.lower(),
    lambda x: x.upper()
]

# %%
list(map(lambda x: x("Hello"), filters))
# Out:
# [5, 'hello', 'HELLO']
